# %%
topics = {
    "ალგებრა": {
        "1": [
            "სიმრავლეები",
            "ოპერაციები სიმრავლეებზე",
            "ვენის დიაგრამები",
        ],
        "2": [
            "ნატურალური რიცხვები",
            "მარტივი და შედგენილი რიცხვები",
            "გამყოფი და ჯერადი",
            "გაყოფადობის ნიშნები",
            "ნაშთები",
        ],
        "3": [
            "მთელი რიცხვები",
        ],
        "4": ["რაციონალური რიცხვები", "წილადები და ათწილადები"],
        "5": ["ირაციონალური რიცხვები", "ნამდვილი რიცხვები"],
        "6": ["რიცხვითი ღერძი"],
        "7": ["რიცხვითი შუალედები"],
        "8": ["რიცხვის მოდული"],
        "9": ["ნატურალური რიცხვების წარმოდგენა სხვადასხვა პოზიციურ სისტემაში"],
        "10": ["პროპორცია"],
        "11": ["რიცხვის პროცენტი და ნაწილი"],
        "12": ["რამდენიმე რიცხვის არითმეტიკული საშუალო"],
        "13": ["ხარისხი ნატურალური და მთელი მაჩვენებლით"],
        "14": ["ერთწევრი და მრავალწევრი"],
        "15": ["შემოკლებული გამრავლების ფორმულები"],
        "16": ["მრავალწევრის დაშლა მამრავლებად"],
        "17": ["რაციონალური გამოსახულება"],
        "19": ["რაციონალურმაჩვენებლიანი ხარისხი"],
        "20": ["ალგებრული გამოსახულება"],
        "21": ["რიცხვის ლოგარითმი"],
        "22": ["მართკუთხა კოორდინატთა სისტემა სიბრტყეზე და სივრცეში"],
        "23": ["ფუნქცია", "ფუნქციის გრაფიკი", "ფუნქციათა კომპოზიცია"],
        "24": ["კუთხის გრადუსული და რადიანული ზომა"],
        "25": ["ტრიგონომეტრიული ფუნქციები: სინუსი, კოსინუსი, ტანგენსი"],
        "26": ["განტოლება", "განტოლებათა სისტემა"],
        "27": ["ერთუცნობიანი წრფივი განტოლებები"],
        "28": ["ერთუცნობიანი კვადრატული განტოლებები"],
        "29": ["კვადრატული სამწევრი"],
        "30": ["ორუცნობიანი ალგებრულ განტოლებათა სისტემები"],
        "31": ["ამოცანები განტოლებისა და განტოლებათა სისტემის შედგენაზე"],
        "32": ["რიცხვითი უტოლობები"],
        "33": ["უტოლობა", "უტოლობათა სისტემა"],
        "34": ["ერთუცნობიანი უტოლობები", "უტოლობათა სისტემები"],
        "35": [
            "წრფივი ფუნქციები და მათი გრაფიკები",
            "კვადრატული ფუნქციები და მათი გრაფიკები",
            "ხარისხოვანი ფუნქციები და მათი გრაფიკები",
            "მაჩვენებლიანი ფუნქციები და მათი გრაფიკები",
            "ლოგარითმული ფუნქციები და მათი გრაფიკები",
            "ტრიგონომეტრიული ფუნქციები და მათი გრაფიკები",
        ],
        "36": ["ირაციონალური განტოლებები"],
        "37": ["მაჩვენებლიანი განტოლებები", "მაჩვენებლიანი უტოლობები"],
        "38": ["ლოგარითმული განტოლებები", "ლოგარითმული უტოლობები"],
        "39": ["ტრიგონომეტრიული განტოლებები"],
        "40": ["რიცხვითი მიმდევრობა"],
        "41": ["არითმეტიკული პროგრესია"],
        "42": ["გეომეტრიული პროგრესია"],
        "43": ["გადანაცვლებათა რიცხვი", "ჯუფთებათა რიცხვი", "წყობათა რიცხვი"],
    },
    "პლანიმეტრია": {
        "1": ["წერტილი, წრფე, სხივი, მონაკვეთი, ტეხილი"],
        "2": ["მონაკვეთის სიგრძე", "ტეხილის სიგრძე"],
        "3": [
            "კუთხე",
            "კუთხის გრადუსული ზომა",
            "მართი, მახვილი, ბლაგვი და გაშლილი კუთხეები",
        ],
        "4": ["კუთხის ბისექტრისა"],
        "5": ["მონაკვეთის შუამართობი"],
        "6": ["მოსაზღვრე და ვერტიკალური კუთხეები"],
        "7": [
            "წრფეთა პარალელობა",
            "ორი წრფის მესამე წრფით გაკვეთისას მიღებული კუთხეები",
        ],
        "8": [
            "კუთხე ორ წრფეს შორის",
            "წრფეთა მართობულობა",
            "მართობი, დახრილი და გეგმილი",
            "მანძილი წერტილიდან წრფემდე",
        ],
        "9": [
            "მრავალკუთხედის ელემენტები: გვერდი, წვერო, კუთხე, დიაგონალი",
            "მრავალკუთხედის პერიმეტრი",
        ],
        "10": ["ამოზნექილი მრავალკუთხედი"],
        "11": [
            "სამკუთხედის ელემენტები: გვერდი, კუთხე, წვერო, მედიანა, ბისექტრისა, სიმაღლე"
        ],
        "12": ["სამკუთხედის კუთხეები"],
        "13": ["სამკუთხედების ტოლობა"],
        "14": ["სამკუთხედების უტოლობა"],
        "15": ["დამოკიდებულებანი სამკუთხედის გვერდებსა და კუთხეებს შორის"],
        "16": ["სამკუთხედის მედიანა"],
        "17": ["სამკუთხედის ბისექტრისა"],
        "18": [
            "სამკუთხედის სახეები: მართკუთხა, მახვილკუთხა, ბლაგვკუთხა, ტოლფერდა, ტოლგვერდა"
        ],
        "19": ["ტოლფერდა სამკუთხედი"],
        "20": [
            "მართკუთხა სამკუთხედის ტოლობის ნიშნები",
            "მართკუთხა სამკუთხედში 30 გრადუსიანი კუთხის მოპირდაპირე კათეტის თვისება",
            "მართკუთხა სამკუთხედში კუთხეებსა და გვერდებს შორის ტრიგონომეტრიული თანაფარდობები",
            "თანაფარდობები ჰიპოტენუზაზე დაშვებულ სიმაღლეს, კათეტებს, კათეტების გეგმილებს და ჰიპოტენუზას შორის",
        ],
        "21": ["პითაგორას თეორემა"],
        "22": ["თალესის თეორემა"],
        "23": ["სამკუთხედის შუახაზი"],
        "24": [
            "სამკუთხედების მსგავსების ნიშნები",
            "მსგავსი სამკუთხედების პერიმეტრებისა და ფართობების შეფარდება",
        ],
        "25": ["სინუსების თეორემა"],
        "26": ["კოსინუსების თეორემა"],
        "27": ["სამკუთხედების ამოხსნა"],
        "28": [
            "პარალელოგრამის გვერდებისა და კუთხეების თვისებები",
            "პარალელოგრამის დიაგონალების თვისებები",
        ],
        "29": ["რომბის დიაგონალების თვისებები"],
        "30": ["მართკუთხედის და კვადრატის დიაგონალების ტოლობა"],
        "31": [
            "ტრაპეციის ელემენტები: ფუძე, ფერდი, სიმაღლე",
            "ტრაპეციის შუახაზის თვისებები",
        ],
        "32": ["ტრაპეციის კერძო სახეები"],
        "33": ["ტოლფერდა ტრაპეცია"],
        "34": ["ბრტყელი ფიგურის ფართობი"],
        "35": [
            "კვადრატის ფართობი",
            "მართკუთხედის ფართობი",
            "სამკუთხედის ფართობი",
            "პარალელოგრამის ფართობი",
            "ტრაპეციის ფართობი",
        ],
        "36": [
            "წრეწირის და წრის ელემენტები: ცენტრი, რადიუსი, დიამეტრი, ქორდა, რკალი, სექტორი, სეგმენტი",
            "რკალის გრადუსული და რადიანული ზომა",
            "რიცხვი π",
            "წრეწირის და მისი რკალის სიგრძის გამოსათვლელი ფორმულები",
            "ქორდის მართობული დიამეტრის თვისება",
        ],
        "37": ["ცენტრალური და ჩახაზული კუთხეები"],
        "38": [
            "წრეწირის მხების თვისება",
            "წერტილიდან წრეწირისადმი გავლებული ორი მხები მონაკვეთის ტოლობა",
            "ურთიერთგადამკვეთი ქორდის თვისებები",
            "წრეწირისადმი ერთი წერტილიდან გავლებული მხებისა და მკვეთის თვისებები",
        ],
        "39": [
            "სამკუთხედში ჩახაზული წრეწირი",
            "სამკუთხედზე შემოხაზული წრეწირი",
        ],
        "40": [
            "წესიერი მრავალკუთხედები",
            "წესიერ მრავალკუთხედში ჩახაზული და შემოხაზული წრეწირები",
        ],
        "41": ["წესიერი მრავალკუთხედის ფართობი"],
        "42": ["წრიული სექტორისა და წრის ფართობი"],
        "43": [
            "ცენტრალური სიმეტრია",
            "ღერძული სიმეტრია",
            "პარალელური გადატანა",
            "ჰომოთეტია",
            "მობრუნება წერტილის გარშემო",
        ],
    },
    "სტერეომეტრია": {
        "1": ["წერტილი, წრფე და სიბრტყე სივრცეში"],
        "2": ["წრფეთა ურთიერთგანლაგება სივრცეში"],
        "3": ["ორთოგონალური დაგეგმილება სიბრტყეზე"],
        "4": ["წრფისა და სიბრტყის მართობულობა"],
        "5": ["წრფისა და სიბრტყის პარალელობა"],
        "6": ["სიბრტყეთა პარალელობა"],
        "7": ["კუთხე სიბრტყეებს შორის"],
        "8": ["სიბრტყეთა მართობულობა"],
        "9": [
            "მონაკვეთი, მართობი და დახრილი",
            "მანძილი წერტილიდან სიბრტყემდე",
            "სამი მართობის თეორემა",
        ],
        "10": ["კუთხე წრფესა და სიბრტყეს შორის"],
        "11": [
            "ორწახნაგა კუთხე",
            "ორწახნაგა კუთხის ზომა",
        ],
        "12": ["მრავალწახნაგა და მისი ელემენტები"],
        "13": ["პრიზმა და მისი ელემენტები"],
        "14": [
            "პრიზმის კერძო სახეები",
            "მართი პრიზმის დიაგონალური კვეთა",
        ],
        "15": ["პირამიდა და მისი ელემენტები"],
        "16": ["წესიერი პირამიდა", "აპოთემა"],
        "17": ["ცილინდრი და მისი ელემენტები"],
        "18": [
            "კონუსი და მისი ელემენტები",
            "კონუსის ღერძული კვეთა",
        ],
        "19": ["ბირთვი, სფერო და მათი ელემენტები"],
        "20": [
            "ბირთვის მხები სიბრტყე",
            "ბირთვის კვეთა სიბრტყით",
        ],
        "21": [
            "სხეულის მოცულობა",
            "გვერდითი და სრული ზედაპირის ფართობი",
        ],
        "22": ["ფიგურების შლილები"],
        "23": [
            "ვექტორების შეკრება",
            "ვექტორის სკალარზე გამრავლება",
            "ვექტორთა სკალარული ნამრავლი",
            "კუთხე ორ ვექტორს შორის",
            "ვექტორის სიგრძე",
            "ვექტორის კორდინატებში",
        ],
    },
    "მონაცემთა ანალიზი, ალბათობა, სტატისტიკა": {
        "1": [
            "დიაგრამები",
            "მასშტაბი",
            "სკალა",
        ],
        "2": [
            "სიხშირე, ფარდობითი სიხშირე",
            "საშუალო",
            "მედიანა",
            "მოდა",
            "გაბნევის დიაპაზონი",
            "საშუალო კვადრატული გადახრა",
        ],
        "3": [
            "ოპერაციები ხდომილობებზე",
            "არათავსებადი ხდომილობები",
            "საწინააღმდეგო ხდომილობა",
            "დამოუკიდებელი ხდომილობები",
            "ხდომილობის ალბათობის გამოთვლა",
            "ხდომილობათა ჯამის ალბათობის გამოთვლა",
            "საწინააღმდეგო ხდომილობის ალბათობის გამოთვლა",
            "დამოუკიდებელ ხდომილობათა ნამრავლის ალბათობის გამოთვლა",
            "გეომეტრიული ალბათობა",
        ],
    },
    "ზომის ერთეულები": {
        "1": ["სიგრძის ერთეულები"],
        "2": ["ფართობის ერთეულები"],
        "3": ["მოცულობის ერთეულები"],
        "4": ["მასის ერთეულები"],
        "5": ["დროის ერთეულები"],
        "6": ["სიჩქარის ერთეულები"],
    },
}

# %%
topics_subenumerated = {}
for t in topics.keys():
    topic_dict = topics[t]
    topic_dict_new = {}
    for st in topic_dict.keys():
        subtopics_list = topic_dict[st]
        subtopics_dict = {}
        for i,sst in enumerate(subtopics_list):
            subtopics_dict[st+f".{i+1}"] = sst
        topic_dict_new[st] = subtopics_dict
    topics_subenumerated[t] = topic_dict_new

# %%
import json
with open('topics.json', 'w', encoding='utf8') as json_file:
    json.dump(topics_subenumerated, json_file, ensure_ascii=False)

# %%
topic_prefixes = {
    "ალგებრა": "ALGEBRA",
    "პლანიმეტრია": "GEO2D",
    "სტერეომეტრია": "GEO3D",
    "მონაცემთა ანალიზი, ალბათობა, სტატისტიკა": "DATA",
    "ზომის ერთეულები": "UNITS",
}

all_topics = {}
for t in topics.keys():
    topic_dict = topics[t]
    for st in topic_dict.keys():
        subtopics_list = topic_dict[st]
        for i, sst in enumerate(subtopics_list):
            all_topics[topic_prefixes[t] + "-" + st + f".{i+1}"] = sst

# %%
import json
with open('all_topics.json', 'w', encoding='utf8') as json_file:
    json.dump(all_topics, json_file, ensure_ascii=False)
